# %%
import numpy as np
import matplotlib.pyplot as plt

population = [87,110,126,138,161,185,210]
increaseRate = [0,26.44,14.55,9.52,16.56,14.85,13.64]
lineLength = [2286,2746,3173,3618,4153,5033,5737]
lineRate = [0,20.1,15.5,14,14.8,21.2,14]
plt.rcParams["font.family"]="SimHei"
colorName = ["lightsteelblue",'lightblue',"lightskyblue","skyblue",'deepskyblue',"cornflowerblue","royalblue","dodgerblue"]
#设置画布，添加子图
fig=plt.figure(num=1,figsize=(8,6))
ax=fig.add_subplot(111)
#画条形图
# ax.bar(x=np.arange(1,8,1),height=population)
ax.set_ylabel("单位：公里")
ax.set_xticklabels([',',"2012年",'2013年','2014年','2015年','2016年','2017年','2018年'],fontsize=12)
ax.set_title("2012-2018我国城市轨道交通运营线路长度统计及增长情况",fontweight='bold')
for a,b in zip(np.linspace(0,8,9),lineLength):
    ax.text(a-0.3,b,"%skm"%b,fontsize=12)
ax.yaxis.grid(linestyle='--',linewidth = 0.4)
ax.bar(x=np.arange(0,7,1),height=lineLength,color=colorName,bottom=0,edgecolor="gold",label="我国城市轨道交通客运人数",linewidth=2,width=0.5,alpha=1)
axRate = ax.twinx()
axRate.plot(["2012年",'2013年','2014年','2015年','2016年','2017年','2018年'],lineRate,color='purple',)
axRate.set_ylim(12,25)
for a,b in zip(np.linspace(0,8,9),lineRate):
    ax.text(a-0.3,b*170,"%s%%"%b,fontsize=12)

axRate.set_ylabel("单位：%")
# Out:
# Text(0,0.5,'单位：%')

# %%
import matplotlib.pyplot as plt
# 数据
plt.figure(dpi=600)
plt.rcParams["font.family"]="SimHei"
labels = ["APM", "市域快铁",  "磁悬浮",'有轨电车',"单轨",'轻轨','地铁']
colorlist = ['red','aqua','yellow','orange','lightgreen','pink','lightblue']
fracs = [10.2,754.6,57.7,417.0,98.5,217.6,5180.6]
# 画图
exp = [0.3,0.3,0.1,0.1,0.1,0.3,0]
_,l_text,p_text=plt.pie(x=fracs, labels=labels,explode=exp,autopct="%0.2f%%",radius=1,labeldistance=0.8,colors=colorlist)
# 展示
for i in l_text:
    i.set_size(12)
for i in p_text:
    i.set_size(8)
plt.legend(loc='best')
plt.savefig("a.png")
plt.show()

# %%
import matplotlib.pyplot as plt
# 数据
plt.figure(dpi=600)
plt.rcParams["font.family"]="SimHei"
# labels = ['浙大网新','上海贝尔','卡斯柯','上海华虹','北京和利时','南京南瑞','赛为股份','其他']
labels = ['南京南瑞','广州杰赛','中铁信','深圳中航','北京和利时','赛为智能','其他']
colorlist = ['dodgerblue','deepskyblue','lightskyblue','skyblue','lightblue','powderblue','cyan','aqua']
# fracs = [4,20,13,12,11,8,7,25]
fracs = [6,9,10,13,15,26,21]
# 画图
exp = [0.3,0.3,0.1,0.1,0.1,0.3,0,0]
_,l_text,p_text=plt.pie(x=fracs, labels=labels,autopct="%0.2f%%",radius=4,labeldistance=0.8,colors=colorlist,wedgeprops=dict(width=2.4,edgecolor='w'))
# 展示
for i in l_text:
    i.set_size(12)
for i in p_text:
    i.set_size(12)
# plt.legend(loc='best')
plt.title("乘客资讯\n及综合安防\n系统",fontsize=14,y=0.38)
# plt.axis([0, 4.5, 0, 4.5])
plt.axis("equal")
plt.savefig("a.png")
plt.show()
